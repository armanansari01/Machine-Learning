# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter("ignore")

# %% [markdown]
# # Exploratory Data Analysis
#
# > * Analysis
# >> 1. Univariate Analysis
# >> 2. Multivariate Analysis
#
# > * Feature Engineering
# >> 1. Creating new columns
# >> 2. Modifying existing ones
#
# > * Handling Outliers
# >> 1. Detect Outliers
# >> 2. Remove Outliers

# %%
df=pd.read_csv('train_titanic.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# ## Categorical columns
# * Survived
# * PClass
# * Sex
# * SibSp
# * Parch
# * Embarked
#
# ## Numerical columns
# * Age
# * Fare
# * PassengerId
#
# ## Mixed columns
# * Name
# * Ticket
# * Cabin

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isnull().mean()*100
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          77.104377
# Embarked        0.224467
# dtype: float64

# %% [markdown]
# > **Observations**
# >> 1. Missing values in Age, Cabin and Embarked
# 2. More than 70% values are missing in Cabin col (will have to drop)
# 3. Few columns have inappropriate data type

# %%
# Dropping cabin columns
df.drop(columns=['Cabin'],inplace=True)

# %%
# Imputing missing values for age
# Strategy - mean

df['Age'].fillna(df['Age'].mean(),inplace=True)

# %%
# Imputing missing values for embarked
# Strategy - most frequent
# finding the most frequent value in embarked col and replacing the NAs with it.

df['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
# So we can see that *'S'* is the most frequently occuring value in Embarked col
df['Embarked'].fillna('S',inplace=True)

# %% [markdown]
# # Changing data type for the following cols
# > * Survived (category)
# > * PClass (category)
# > * Sex (category)
# > * Age (int)
# > * Embarked (category)

# %%
df['Survived'] = df['Survived'].astype('category')
df['Pclass'] = df['Pclass'].astype('category')
df['Sex'] = df['Sex'].astype('category')
df['Embarked'] = df['Embarked'].astype('category')
df['Age'] = df['Age'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    category
#  2   Pclass       891 non-null    category
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    category
#  5   Age          891 non-null    int32
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     891 non-null    category
# dtypes: category(4), float64(1), int32(1), int64(3), object(2)
# memory usage: 49.4+ KB

# %%
df.describe()
# Out:
#        PassengerId         Age       SibSp       Parch        Fare
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000   29.544332    0.523008    0.381594   32.204208
# std     257.353842   13.013778    1.102743    0.806057   49.693429
# min       1.000000    0.000000    0.000000    0.000000    0.000000
# 25%     223.500000   22.000000    0.000000    0.000000    7.910400
# 50%     446.000000   29.000000    0.000000    0.000000   14.454200
# 75%     668.500000   35.000000    1.000000    0.000000   31.000000
# max     891.000000   80.000000    8.000000    6.000000  512.329200

# %%
# Target distribution analysis
fig, ax = plt.subplots(1,2)

plt.style.use('fivethirtyeight')
plt.figure(figsize=(3,4))
sns.set_context("paper",font_scale=1.2)
sns.countplot(df,x='Survived',ax=ax[0])
df['Survived'].value_counts().plot.pie(explode=[0,0.2],autopct='%1.2f%%',ax=ax[1])
fig.show()

# %%
sns.displot(data=df,kind='hist',x='Age',hue='Survived',multiple='stack',bins=25,height=4,aspect=1.7)

# %%
sns.displot(data=df,kind='hist',x='Fare',hue='Survived',multiple='stack',bins=25,height=4,aspect=1.7)

# %%
ecnt = print((df['Embarked'].value_counts()/891)*100)
ecnt
sns.countplot(df,x='Embarked')
# Out:
# Embarked
# S    72.502806
# C    18.855219
# Q     8.641975
# Name: count, dtype: float64
# <Axes: xlabel='Embarked', ylabel='count'>

# %%
# Age column
sns.distplot(df['Age'])
print(df['Age'].skew())  # skewness
print(df['Age'].kurt())  # peakedness
# Out:
# 0.45956263424701577
# 0.9865867453652877

# %%
sns.boxplot(df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
print('People with age range between 60 and 70 are : ',df[(df['Age']>60) & (df['Age']<70)].shape[0])
print('People with age range between 70 and 75 are : ',df[(df['Age']>70) & (df['Age']<75)].shape[0])
print('People with age greater than 75 are : ',df[(df['Age']>75)].shape[0])

print('-'*50)

print('People with age between 0 and 1 are : ',df[(df['Age']<1)].shape[0])
# Out:
# People with age range between 60 and 70 are :  15
# People with age range between 70 and 75 are :  3
# People with age greater than 75 are :  1
# --------------------------------------------------
# People with age between 0 and 1 are :  7

# %% [markdown]
# ### Observation
# * For all practical purposes age can be considered as normal distribution
# * Deeper analysis is required for outlier detection

# %%
# Fare column
sns.distplot(df['Fare'])
print(df['Fare'].skew()) # skewness
print(df['Fare'].kurt()) # peakedness
# Out:
# 4.787316519674893
# 33.39814088089868

# %%
sns.boxplot(df['Fare'])
# Out:
# <Axes: ylabel='Fare'>

# %%
print("People with fare in between $200 and $300 are : ",df[(df['Fare']>200) & (df['Fare']<300)].shape[0])
print("People with fare greater than $300 are : ",df[df['Fare']>300].shape[0])
# Out:
# People with fare in between $200 and $300 are :  17
# People with fare greater than $300 are :  3

# %% [markdown]
# ### Observations
# * Highly skewed data, a lot of people had cheaper tickets
# * Outliers are there in the data

# %%
# Multivariate analysis
# Survival with Class of passengers
pd.crosstab(df['Pclass'],df['Survived']).apply(lambda r: round((r/r.sum())*100,1),axis=1)
# Out:
# Survived     0     1
# Pclass
# 1         37.0  63.0
# 2         52.7  47.3
# 3         75.8  24.2

# %%
sns.displot(data=df,kind='hist',x='Pclass',hue='Survived',multiple='stack',bins=3,height=4,aspect=1.7)

# %%
# Survival with Sex
pd.crosstab(df['Sex'],df['Survived']).apply(lambda r: round((r/r.sum())*100,1),axis=1)
# Out:
# Survived     0     1
# Sex
# female    25.8  74.2
# male      81.1  18.9

# %%
sns.displot(data=df,kind='hist',x='Sex',hue='Survived',multiple='stack',bins=25,height=4,aspect=1.7)

# %%
# Survival with Embarked
pd.crosstab(df['Embarked'],df['Survived']).apply(lambda r: round((r/r.sum())*100,1),axis=1)
# Out:
# Survived     0     1
# Embarked
# C         44.6  55.4
# Q         61.0  39.0
# S         66.1  33.9

# %%
sns.displot(data=df,kind='hist',x='Embarked',hue='Survived',multiple='stack',bins=25,height=4,aspect=1.7)

# %%
# Survival with Age
plt.figure(figsize=(15,6))
sns.distplot(df[df['Survived']==0]['Age'])
sns.distplot(df[df['Survived']==1]['Age'])
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
plt.figure(figsize=(15,6))
sns.distplot(df[df['Survived']==0]['Fare'])
sns.distplot(df[df['Survived']==1]['Fare'])
# Out:
# <Axes: xlabel='Fare', ylabel='Density'>

# %%
sns.pairplot(df)

# %%
sns.heatmap(df[['PassengerId','Age','SibSp','Parch','Fare']].corr(),annot=True)
# Out:
# <Axes: >

# %%
# Feature Engineering
# Since SibSp and Parch are family members and are given in two different cols, it is getting difficult to analyze both of them.
# So we will create a new col named fam_members which will denote the total members in the family i.e., the sum of Parch and SibSp
df['fam_members'] = df['Parch'] + df['SibSp']

# %%
df.sample(5)
# Out:
#      PassengerId Survived Pclass                         Name   Sex  Age  \
# 48            49        0      3          Samaan, Mr. Youssef  male   29
# 193          194        1      2   Navratil, Master. Michel M  male    3
# 840          841        0      3  Alhomaki, Mr. Ilmari Rudolf  male   20
# 732          733        0      2         Knight, Mr. Robert J  male   29
# 468          469        0      3           Scanlan, Mr. James  male   29
#
#      SibSp  Parch            Ticket     Fare Embarked  fam_members
# 48       2      0              2662  21.6792        C            2
# 193      1      1            230080  26.0000        S            2
# 840      0      0  SOTON/O2 3101287   7.9250        S            0
# 732      0      0            239855   0.0000        S            0
# 468      0      0             36209   7.7250        Q            0

# %%
# Now we will engineer a new feature by the name of family type

def family_type(num):
    if num == 0:
        return "Alone"
    elif num>0 and num<=4:
        return "Medium"
    else:
        return "Large"

# %%
df['fam_type'] = df['fam_members'].apply(family_type)

# %%
df.sample(5)
# Out:
#      PassengerId Survived Pclass                                   Name  \
# 619          620        0      2                    Gavey, Mr. Lawrence
# 249          250        0      2          Carter, Rev. Ernest Courtenay
# 437          438        1      2  Richards, Mrs. Sidney (Emily Hocking)
# 212          213        0      3                 Perkin, Mr. John Henry
# 163          164        0      3                        Calic, Mr. Jovo
#
#         Sex  Age  SibSp  Parch     Ticket     Fare Embarked  fam_members  \
# 619    male   26      0      0      31028  10.5000        S            0
# 249    male   54      1      0     244252  26.0000        S            1
# 437  female   24      2      3      29106  18.7500        S            5
# 212    male   22      0      0  A/5 21174   7.2500        S            0
# 163    male   17      0      0     315093   8.6625        S            0
#
#     fam_type
# 619    Alone
# 249   Medium
# 437    Large
# 212    Alone
# 163    Alone

# %%
# Dropping SibSp, Parch and fam_members

df.drop(columns=['SibSp','Parch','fam_members'],inplace=True)

# %%
df.sample(5)
# Out:
#      PassengerId Survived Pclass                                   Name  \
# 389          390        1      2                  Lehmann, Miss. Bertha
# 648          649        0      3                     Willey, Mr. Edward
# 331          332        0      1                    Partner, Mr. Austen
# 182          183        0      3  Asplund, Master. Clarence Gustaf Hugo
# 344          345        0      2                Fox, Mr. Stanley Hubert
#
#         Sex  Age         Ticket     Fare Embarked fam_type
# 389  female   17        SC 1748  12.0000        C    Alone
# 648    male   29  S.O./P.P. 751   7.5500        S    Alone
# 331    male   45         113043  28.5000        S    Alone
# 182    male    9         347077  31.3875        S    Large
# 344    male   36         229236  13.0000        S    Alone

# %%
pd.crosstab(df['fam_type'],df['Survived']).apply(lambda r: round((r/r.sum())*100,1),axis=1)
# Out:
# Survived     0     1
# fam_type
# Alone     69.6  30.4
# Large     85.1  14.9
# Medium    44.0  56.0

# %% [markdown]
# ### Detecting outliers
#
# #### Numerical data
#
# * if the data is following normal distrubution, anything beyond 3SD-mean + 3SD can be considered as an outlier
# * if the data does not follow normal distribution, using boxplot we can eliminate points beyond Q1-1.5 *IQR* and Q3+1.5 *IQR*
#
# #### Categorical data
# * if the col is highly imbalanced for eg: male 10000 and female 2 then we can eliminate female

# %%
# Handling outliers in Age
df = df[df['Age']<(df['Age'].mean() + 3 * df['Age'].std())]
df.shape
# Out:
# (884, 10)

# %%
# Handling outliers from Fare column
# Finding quartiles

Q1 = np.percentile(df['Fare'],25)
Q3 = np.percentile(df['Fare'],75)

outlier_low = Q1 - 1.5 * (Q3 - Q1)
outlier_high = Q3 + 1.5 * (Q3 - Q1)

df = df[(df['Fare']>outlier_low) & (df['Fare']<outlier_high)]

# %%
# One hot encoding
# Cols to be transformed are Pclass, Sex, Embarked, fam_type

df = pd.get_dummies(data=df,columns=['Pclass','Sex','Embarked','fam_type'],drop_first=True)
df
# Out:
#      PassengerId Survived                                          Name  Age  \
# 0              1        0                       Braund, Mr. Owen Harris   22
# 2              3        1                        Heikkinen, Miss. Laina   26
# 3              4        1  Futrelle, Mrs. Jacques Heath (Lily May Peel)   35
# 4              5        0                      Allen, Mr. William Henry   35
# 5              6        0                              Moran, Mr. James   29
# ..           ...      ...                                           ...  ...
# 886          887        0                         Montvila, Rev. Juozas   27
# 887          888        1                  Graham, Miss. Margaret Edith   19
# 888          889        0      Johnston, Miss. Catherine Helen "Carrie"   29
# 889          890        1                         Behr, Mr. Karl Howell   26
# 890          891        0                           Dooley, Mr. Patrick   32
#
# ...

# %%
plt.figure(figsize=(15,6))
sns.heatmap(df.drop(['Name','Ticket','Survived'],axis=1).corr(),cmap='summer',annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## Observations
# * Chance of female survival is higher than male survival
# * Travelling in Pclass 3 was deadliest
# * Somehow, people going to C survived more
# * People in the age range of 20 to 40 had a higher chance of not surviving
# * People travelling with smaller families has a higher chance of surviving the accident in comparison to people with large families and travelling alone.

# %% [markdown]
# # Model Building

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
X = df.drop(['Survived','Name','Ticket'],axis=1)
y = df['Survived']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
clf = RandomForestClassifier()

param_grid = [
    {
        "n_estimators":[10,100,200,500],
        "max_depth": [None,5,10],
        "min_samples_split": [2,3,4]
    }
]

grid_search = GridSearchCV(clf,param_grid,cv=3,scoring='accuracy',return_train_score=True)
grid_search.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=3, estimator=RandomForestClassifier(),
#              param_grid=[{'max_depth': [None, 5, 10],
#                           'min_samples_split': [2, 3, 4],
#                           'n_estimators': [10, 100, 200, 500]}],
#              return_train_score=True, scoring='accuracy')

# %%
final_clf = grid_search.best_estimator_

# %%
final_clf
# Out:
# RandomForestClassifier(max_depth=5, min_samples_split=4, n_estimators=200)

# %%
final_clf.fit(X_train,y_train)
# Out:
# RandomForestClassifier(max_depth=5, min_samples_split=4, n_estimators=200)

# %%
y_pred = final_clf.predict(X_test)

# %%
accuracy_score(y_pred,y_test)
# Out:
# 0.7922077922077922
